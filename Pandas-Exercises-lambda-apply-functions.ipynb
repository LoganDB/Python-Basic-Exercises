# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
df1=pd.read_csv("student-mat.csv")
df2=pd.read_csv("student-por.csv")

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df=pd.merge(left=df1,right=df2,how='outer',sort=True)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob   Fjob  ...  \
# 0     GP   F   15       R     GT3       T     1     1  at_home  other  ...
# 1     GP   F   15       R     GT3       T     1     1  at_home  other  ...
# 2     GP   F   15       R     GT3       T     1     1    other  other  ...
# 3     GP   F   15       R     GT3       T     1     1    other  other  ...
# 4     GP   F   15       R     GT3       T     1     1    other  other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      3        1      2     1     1      1        4  13  13  13
# 1      3        1      2     1     1      1        2   7  10  10
# 2      5        5      5     1     1      1        2   8   9   9
# 3      3        3      4     2     4      5        2  13  11  11
# 4      3        3      4     2     4      5        2   8   6   5
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
stud_alcoh = df.loc[: , "school":"guardian"]
stud_alcoh.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob   Fjob  \
# 0     GP   F   15       R     GT3       T     1     1  at_home  other
# 1     GP   F   15       R     GT3       T     1     1  at_home  other
# 2     GP   F   15       R     GT3       T     1     1    other  other
# 3     GP   F   15       R     GT3       T     1     1    other  other
# 4     GP   F   15       R     GT3       T     1     1    other  other
#
#        reason guardian
# 0        home   mother
# 1        home   mother
# 2      course   mother
# 3  reputation   mother
# 4  reputation   mother

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
capitalize = lambda x: x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
stud_alcoh['Mjob'].apply(capitalize)
stud_alcoh['Fjob'].apply(capitalize)
# Out:
# 0          Other
# 1          Other
# 2          Other
# 3          Other
# 4          Other
#           ...
# 1039    Services
# 1040     At_home
# 1041       Other
# 1042    Services
# 1043       Other
# Name: Fjob, Length: 1044, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
stud_alcoh.tail()
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1039     MS   M   19       U     GT3       T     3     2   at_home  services
# 1040     MS   M   19       U     LE3       T     1     1     other   at_home
# 1041     MS   M   20       R     GT3       T     1     1     other     other
# 1042     MS   M   20       U     LE3       A     2     2  services  services
# 1043     MS   M   21       R     GT3       T     1     1     other     other
#
#       reason guardian
# 1039  course   mother
# 1040  course   father
# 1041  course    other
# 1042  course    other
# 1043  course    other

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
stud_alcoh['Mjob'] = stud_alcoh['Mjob'].apply(capitalize)
stud_alcoh['Fjob'] = stud_alcoh['Fjob'].apply(capitalize)
stud_alcoh.tail()
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1039     MS   M   19       U     GT3       T     3     2   At_home  Services
# 1040     MS   M   19       U     LE3       T     1     1     Other   At_home
# 1041     MS   M   20       R     GT3       T     1     1     Other     Other
# 1042     MS   M   20       U     LE3       A     2     2  Services  Services
# 1043     MS   M   21       R     GT3       T     1     1     Other     Other
#
#       reason guardian
# 1039  course   mother
# 1040  course   father
# 1041  course    other
# 1042  course    other
# 1043  course    other

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if x > 18:
        return True
    else:
        return False

# %%
stud_alcoh['legal_drinker'] = stud_alcoh['age'].apply(majority)
stud_alcoh.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob   Fjob  \
# 0     GP   F   15       R     GT3       T     1     1  At_home  Other
# 1     GP   F   15       R     GT3       T     1     1  At_home  Other
# 2     GP   F   15       R     GT3       T     1     1    Other  Other
# 3     GP   F   15       R     GT3       T     1     1    Other  Other
# 4     GP   F   15       R     GT3       T     1     1    Other  Other
#
#        reason guardian  legal_drinker
# 0        home   mother          False
# 1        home   mother          False
# 2      course   mother          False
# 3  reputation   mother          False
# 4  reputation   mother          False

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
def times_10(x):
    if type(x) is int:
        return 10 * x
    return x

# %%
stud_alcoh.applymap(times_10).head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F  150       R     GT3       T    10    10   At_home     Other
# 1     GP   F  150       R     GT3       T    10    10   At_home     Other
# 2     GP   F  150       R     GT3       T    10    10     Other     Other
# 3     GP   F  150       R     GT3       T    10    10     Other     Other
# 4     GP   F  150       R     GT3       T    10    10     Other     Other
# 5     GP   F  150       R     GT3       T    20    20   At_home     Other
# 6     GP   F  150       R     GT3       T    20    20   At_home     Other
# 7     GP   F  150       R     GT3       T    20    40  Services    Health
# 8     GP   F  150       R     GT3       T    20    40  Services    Health
# 9     GP   F  150       R     GT3       T    30    30  Services  Services
#
#        reason guardian  legal_drinker
# 0        home   mother          False
# 1        home   mother          False
# 2      course   mother          False
# 3  reputation   mother          False
# 4  reputation   mother          False
# 5  reputation   mother          False
# 6  reputation   mother          False
# 7      course   mother          False
# 8      course   mother          False
# 9  reputation    other          False
